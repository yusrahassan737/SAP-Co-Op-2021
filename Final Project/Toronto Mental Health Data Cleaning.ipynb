# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Mental_Health_Crisis Lines_and_Support Services_-_Toronto.csv')
df2 = pd.read_csv('neighbourhood-profiles-2016-csv.csv')

# %%
df
# Out:
#     _id  OBJECTID                                        AGENCY_NAME  \
# 0     1      1236                              St Michael's Hospital
# 1     2      1237                              St Michael's Hospital
# 2     3      1238                       WoodGreen Community Services
# 3     4      1239            Bangladeshi Canadian Community Services
# 4     5      1240              Harriet Tubman Community Organization
# ..  ...       ...                                                ...
# 94   95      1233             Centre for Addiction and Mental Health
# 95   96      1234             Centre for Addiction and Mental Health
# 96   97      1235         Vasantham, A Tamil Seniors Wellness Centre
# 97   98      1241                                    Youth Unlimited
# 98   99      1242  WoodGreen Community Services - WoodGreen Commu...
#
#                                  ORGANIZATION_ADDRESS  \
# 0               21 McGill St, Toronto, ON     M5B 1H3
# ...

# %%
df2
# Out:
#        _id                   Category  \
# 0        1  Neighbourhood Information
# 1        2  Neighbourhood Information
# 2        3                 Population
# 3        4                 Population
# 4        5                 Population
# ...    ...                        ...
# 2378  2379                   Mobility
# 2379  2380                   Mobility
# 2380  2381                   Mobility
# 2381  2382                   Mobility
# 2382  2383                   Mobility
#
#                                                  Topic  \
# 0                            Neighbourhood Information
# 1                            Neighbourhood Information
# 2                             Population and dwellings
# 3                             Population and dwellings
# 4                             Population and dwellings
# ...                                                ...
# 2378  Mobility status - Place of residence 5 years ago
# ...

# %%
print(df2)
# Out:
#        _id                   Category  \
# 0        1  Neighbourhood Information
# 1        2  Neighbourhood Information
# 2        3                 Population
# 3        4                 Population
# 4        5                 Population
# ...    ...                        ...
# 2378  2379                   Mobility
# 2379  2380                   Mobility
# 2380  2381                   Mobility
# 2381  2382                   Mobility
# 2382  2383                   Mobility
#
#                                                  Topic  \
# 0                            Neighbourhood Information
# 1                            Neighbourhood Information
# 2                             Population and dwellings
# 3                             Population and dwellings
# 4                             Population and dwellings
# ...                                                ...
# 2378  Mobility status - Place of residence 5 years ago
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Length: 99, dtype: bool

# %%
df2.info
# Out:
# <bound method DataFrame.info of        _id                   Category  \
# 0        1  Neighbourhood Information
# 1        2  Neighbourhood Information
# 2        3                 Population
# 3        4                 Population
# 4        5                 Population
# ...    ...                        ...
# 2378  2379                   Mobility
# 2379  2380                   Mobility
# 2380  2381                   Mobility
# 2381  2382                   Mobility
# 2382  2383                   Mobility
#
#                                                  Topic  \
# 0                            Neighbourhood Information
# 1                            Neighbourhood Information
# 2                             Population and dwellings
# 3                             Population and dwellings
# 4                             Population and dwellings
# ...                                                ...
# 2378  Mobility status - Place of residence 5 years ago
# ...
